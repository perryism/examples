# %%
# %matplotlib inline
import pyfolio as pf

stock_rets = pf.utils.get_symbol_rets('fb')
pf.create_returns_tear_sheet(stock_rets, live_start_date=stock_rets.index[-40])
# Out:
# Entire data start date: 2012-05-21
# Entire data end date: 2017-09-19
# In-sample months: 62
# Out-of-sample months: 1
#                         All In-sample Out-of-sample
# Annual return         32.7%     32.9%         27.5%
# Cumulative returns   351.3%    334.2%          3.9%
# Annual volatility     37.8%     38.3%         16.8%
# Sharpe ratio           0.93      0.93          1.53
# Calmar ratio           0.61      0.61          7.73
# Stability              0.92      0.91          0.21
# Max drawdown         -53.6%    -53.6%         -3.6%
# Omega ratio            1.20      1.20          1.28
# Sortino ratio          1.50      1.49          2.36
# Skew                   1.90      1.89          0.05
# Kurtosis              23.90     23.39          0.16
# Tail ratio             1.12      1.10          0.83
# Daily value at risk   -4.6%     -4.7%         -2.0%
# Alpha                  0.19      0.20          0.11
# Beta                   1.04      1.04          1.31
# ...
