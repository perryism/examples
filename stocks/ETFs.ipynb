# %%
import urllib
etfs = urllib.urlopen("http://www.nasdaq.com/investing/etfs/etf-finder-results.aspx?download=Yes").read()

# %%
import pandas as pd
from StringIO import StringIO
pd.read_csv(StringIO(etfs))
# Out:
#      Symbol                                               Name  LastSale  \
# 0       FMF  First Trust Morningstar Managed Futures Strate...   45.9400
# 1       FMK                 First Trust Mega Cap AlphaDEX Fund   31.0210
# 2      FNCL                 Fidelity MSCI Financials Index ETF   37.3100
# 3      FNDA    Schwab Fundamental U.S. Small Company Index ETF   34.7900
# 4      FNDB     Schwab Fundamental U.S. Broad Market Index ETF   34.3062
# 5      FNDC  Schwab Fundamental International Small Company...   33.9600
# 6      FNDE  Schwab Fundamental Emerging Markets Large Comp...   28.2250
# 7      FNDF  Schwab Fundamental International Large Company...   29.1500
# 8      FNDX    Schwab Fundamental U.S. Large Company Index ETF   34.4700
# 9       FNI                            First Trust Chindia ETF   38.0900
# 10      FNK            First Trust Mid Cap Value AlphaDEX Fund   33.6605
# 11      FNX             First Trust Mid Cap Core AlphaDEX Fund   59.8300
# ...
